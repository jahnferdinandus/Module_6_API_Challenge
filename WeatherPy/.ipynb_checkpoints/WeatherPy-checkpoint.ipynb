# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 603

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"  # Use units=metric for Celsius
    
    # Log the URL, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Increment the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Make the API request
        city_weather = requests.get(city_url).json()

        # Parse out the desired weather data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]  # Temperature is already in Celsius
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"City not found. Skipping... ({e})")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | prince rupert
# Processing Record 2 of Set 1 | jiuquan
# Processing Record 3 of Set 1 | edinburgh of the seven seas
# Processing Record 4 of Set 1 | yeraliyev
# Processing Record 5 of Set 1 | posto fiscal rolim de moura
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | beihai
# Processing Record 8 of Set 1 | enewetak
# Processing Record 9 of Set 1 | puerto natales
# Processing Record 10 of Set 1 | kalix
# Processing Record 11 of Set 1 | grytviken
# Processing Record 12 of Set 1 | nadi
# Processing Record 13 of Set 1 | adamstown
# Processing Record 14 of Set 1 | waitangi
# Processing Record 15 of Set 1 | tank
# Processing Record 16 of Set 1 | thompson
# Processing Record 17 of Set 1 | weatherford
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | ataq
# Processing Record 20 of Set 1 | mogocha
# Processing Record 21 of Set 1 | klaksvik
# Processing Record 22 of Set 1 | west island
# Processing Record 23 of Set 1 | taiohae
# City not found. Skipping... ('coord')
# Processing Record 24 of Set 1 | stanley
# Processing Record 25 of Set 1 | kalabagh
# Processing Record 26 of Set 1 | port-aux-francais
# Processing Record 27 of Set 1 | ash shafa
# City not found. Skipping... ('coord')
# Processing Record 28 of Set 1 | papatowai
# Processing Record 29 of Set 1 | bakanas
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | nar'yan-mar
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | invercargill
# Processing Record 34 of Set 1 | rio grande
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | anadyr
# Processing Record 37 of Set 1 | sept-iles
# Processing Record 38 of Set 1 | nyurba
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | khandwa
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | cannonvale
# Processing Record 43 of Set 1 | kingston
# Processing Record 44 of Set 1 | bethel
# Processing Record 45 of Set 1 | porto novo
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | malango
# Processing Record 49 of Set 1 | iqaluit
# Processing Record 50 of Set 1 | bamboo flat
# Processing Record 0 of Set 2 | utrik
# Processing Record 1 of Set 2 | punta del este
# Processing Record 2 of Set 2 | baharly
# Processing Record 3 of Set 2 | whangarei
# Processing Record 4 of Set 2 | san matias
# Processing Record 5 of Set 2 | zhangye
# Processing Record 6 of Set 2 | san patricio
# Processing Record 7 of Set 2 | bahia de caraquez
# Processing Record 8 of Set 2 | kabalo
# Processing Record 9 of Set 2 | hami
# Processing Record 10 of Set 2 | wiang sa
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | adrar
# Processing Record 13 of Set 2 | tofol
# Processing Record 14 of Set 2 | ushtobe
# Processing Record 15 of Set 2 | taman rajawali
# City not found. Skipping... ('coord')
# Processing Record 16 of Set 2 | margaret river
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | san luis
# Processing Record 19 of Set 2 | awjilah
# Processing Record 20 of Set 2 | green river
# Processing Record 21 of Set 2 | port mathurin
# Processing Record 22 of Set 2 | luanda
# Processing Record 23 of Set 2 | nouadhibou
# Processing Record 24 of Set 2 | bontang
# Processing Record 25 of Set 2 | san juan cosala
# Processing Record 26 of Set 2 | astorga
# Processing Record 27 of Set 2 | bemidji
# Processing Record 28 of Set 2 | sao tome
# Processing Record 29 of Set 2 | kirakira
# Processing Record 30 of Set 2 | la passe
# Processing Record 31 of Set 2 | mount gambier
# Processing Record 32 of Set 2 | mo i rana
# Processing Record 33 of Set 2 | hawaiian paradise park
# Processing Record 34 of Set 2 | manta
# Processing Record 35 of Set 2 | fale old settlement
# Processing Record 36 of Set 2 | antonio enes
# Processing Record 37 of Set 2 | umm ruwaba
# Processing Record 38 of Set 2 | novo aripuana
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | verkh-chebula
# Processing Record 41 of Set 2 | tchamba
# Processing Record 42 of Set 2 | ma'an
# Processing Record 43 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 44 of Set 2 | mananara
# Processing Record 45 of Set 2 | jayapura
# Processing Record 46 of Set 2 | olinda
# Processing Record 47 of Set 2 | ribas do rio pardo
# Processing Record 48 of Set 2 | pierre
# Processing Record 49 of Set 2 | kenora
# Processing Record 0 of Set 3 | swakopmund
# Processing Record 1 of Set 3 | port saint john's
# Processing Record 2 of Set 3 | tranovaho
# City not found. Skipping... ('coord')
# Processing Record 3 of Set 3 | sandnessjoen
# Processing Record 4 of Set 3 | peterhead
# Processing Record 5 of Set 3 | xam nua
# Processing Record 6 of Set 3 | isafjordur
# Processing Record 7 of Set 3 | ciudad lazaro cardenas
# Processing Record 8 of Set 3 | minas de marcona
# Processing Record 9 of Set 3 | mount isa
# Processing Record 10 of Set 3 | raholt
# Processing Record 11 of Set 3 | san antonio de pale
# Processing Record 12 of Set 3 | pacific grove
# Processing Record 13 of Set 3 | olonkinbyen
# Processing Record 14 of Set 3 | pyapon
# Processing Record 15 of Set 3 | aasiaat
# Processing Record 16 of Set 3 | northam
# Processing Record 17 of Set 3 | sabha
# Processing Record 18 of Set 3 | badger
# Processing Record 19 of Set 3 | new norfolk
# Processing Record 20 of Set 3 | st. john's
# Processing Record 21 of Set 3 | burang
# Processing Record 22 of Set 3 | lompoc
# Processing Record 23 of Set 3 | cavan
# Processing Record 24 of Set 3 | san luis de la loma
# Processing Record 25 of Set 3 | puerto baquerizo moreno
# Processing Record 26 of Set 3 | bubaque
# Processing Record 27 of Set 3 | bilibino
# Processing Record 28 of Set 3 | longyearbyen
# Processing Record 29 of Set 3 | alice springs
# Processing Record 30 of Set 3 | vorgashor
# Processing Record 31 of Set 3 | aral
# Processing Record 32 of Set 3 | mukalla
# Processing Record 33 of Set 3 | lms
# City not found. Skipping... ('coord')
# Processing Record 34 of Set 3 | manokwari
# Processing Record 35 of Set 3 | iranshahr
# Processing Record 36 of Set 3 | colares
# Processing Record 37 of Set 3 | mata-utu
# Processing Record 38 of Set 3 | veraval
# Processing Record 39 of Set 3 | afaahiti
# Processing Record 40 of Set 3 | greymouth
# Processing Record 41 of Set 3 | vel'sk
# Processing Record 42 of Set 3 | zardob
# Processing Record 43 of Set 3 | kirensk
# Processing Record 44 of Set 3 | guerrero negro
# Processing Record 45 of Set 3 | darwin
# Processing Record 46 of Set 3 | faya-largeau
# Processing Record 47 of Set 3 | nova sintra
# Processing Record 48 of Set 3 | ytyk-kyuyel'
# City not found. Skipping... ('coord')
# Processing Record 49 of Set 3 | mahajanga
# Processing Record 0 of Set 4 | tsiombe
# Processing Record 1 of Set 4 | coquimbo
# Processing Record 2 of Set 4 | lihue
# Processing Record 3 of Set 4 | kapuskasing
# Processing Record 4 of Set 4 | luderitz
# Processing Record 5 of Set 4 | weno
# Processing Record 6 of Set 4 | midvagur
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | kailua-kona
# Processing Record 9 of Set 4 | nemencine
# Processing Record 10 of Set 4 | ayaguz
# City not found. Skipping... ('coord')
# Processing Record 11 of Set 4 | malvan
# Processing Record 12 of Set 4 | bandar seri begawan
# Processing Record 13 of Set 4 | portland
# Processing Record 14 of Set 4 | grande prairie
# Processing Record 15 of Set 4 | college
# Processing Record 16 of Set 4 | pechora
# Processing Record 17 of Set 4 | geraldton
# Processing Record 18 of Set 4 | udachny
# Processing Record 19 of Set 4 | yellowknife
# Processing Record 20 of Set 4 | nuuk
# Processing Record 21 of Set 4 | tacna
# Processing Record 22 of Set 4 | totness
# Processing Record 23 of Set 4 | blackmans bay
# Processing Record 24 of Set 4 | al muwayh
# Processing Record 25 of Set 4 | benguela
# Processing Record 26 of Set 4 | loreto
# Processing Record 27 of Set 4 | tura
# Processing Record 28 of Set 4 | cabo san lucas
# Processing Record 29 of Set 4 | severo-yeniseyskiy
# Processing Record 30 of Set 4 | iskateley
# Processing Record 31 of Set 4 | joao camara
# Processing Record 32 of Set 4 | laminusa
# Processing Record 33 of Set 4 | vadso
# Processing Record 34 of Set 4 | bafra
# Processing Record 35 of Set 4 | san andres
# Processing Record 36 of Set 4 | mersa matruh
# Processing Record 37 of Set 4 | lebu
# Processing Record 38 of Set 4 | fort st. john
# Processing Record 39 of Set 4 | bardai
# Processing Record 40 of Set 4 | vila velha
# Processing Record 41 of Set 4 | escanaba
# Processing Record 42 of Set 4 | takoradi
# Processing Record 43 of Set 4 | penzance
# Processing Record 44 of Set 4 | ostrow wielkopolski
# Processing Record 45 of Set 4 | at taj
# Processing Record 46 of Set 4 | namtsy
# Processing Record 47 of Set 4 | puerto colombia
# Processing Record 48 of Set 4 | remire-montjoly
# Processing Record 49 of Set 4 | sinj
# Processing Record 0 of Set 5 | lerwick
# Processing Record 1 of Set 5 | alesund
# Processing Record 2 of Set 5 | sainte-anne-des-monts
# Processing Record 3 of Set 5 | cargados carajos
# City not found. Skipping... ('coord')
# Processing Record 4 of Set 5 | langsa
# Processing Record 5 of Set 5 | wailua homesteads
# Processing Record 6 of Set 5 | karagay
# Processing Record 7 of Set 5 | klyuchi
# Processing Record 8 of Set 5 | pisco
# Processing Record 9 of Set 5 | ciudad acuna
# Processing Record 10 of Set 5 | codrington
# Processing Record 11 of Set 5 | taoudenni
# Processing Record 12 of Set 5 | winnemucca
# Processing Record 13 of Set 5 | lent'ekhi
# Processing Record 14 of Set 5 | yagoua
# Processing Record 15 of Set 5 | ust-nera
# Processing Record 16 of Set 5 | ulanhot
# Processing Record 17 of Set 5 | port-cartier
# Processing Record 18 of Set 5 | san jose village
# City not found. Skipping... ('coord')
# Processing Record 19 of Set 5 | surgut
# Processing Record 20 of Set 5 | askino
# Processing Record 21 of Set 5 | birni n konni
# Processing Record 22 of Set 5 | howrah
# Processing Record 23 of Set 5 | concepcion
# Processing Record 24 of Set 5 | atafu village
# Processing Record 25 of Set 5 | humberto de campos
# Processing Record 26 of Set 5 | sakakah
# Processing Record 27 of Set 5 | devinuwara
# City not found. Skipping... ('coord')
# Processing Record 28 of Set 5 | bereznik
# Processing Record 29 of Set 5 | port blair
# Processing Record 30 of Set 5 | kununurra
# Processing Record 31 of Set 5 | zadar
# Processing Record 32 of Set 5 | holdenville
# Processing Record 33 of Set 5 | sao vicente
# Processing Record 34 of Set 5 | whitehorse
# Processing Record 35 of Set 5 | fiche
# Processing Record 36 of Set 5 | bengkulu
# Processing Record 37 of Set 5 | miri
# Processing Record 38 of Set 5 | arawa
# Processing Record 39 of Set 5 | mungyeong
# Processing Record 40 of Set 5 | sisimiut
# Processing Record 41 of Set 5 | constantia
# Processing Record 42 of Set 5 | messini
# Processing Record 43 of Set 5 | kataragama
# City not found. Skipping... ('coord')
# Processing Record 44 of Set 5 | laojunmiao
# Processing Record 45 of Set 5 | spring creek
# Processing Record 46 of Set 5 | nookat
# City not found. Skipping... ('coord')
# Processing Record 47 of Set 5 | rawson
# Processing Record 48 of Set 5 | san pedro pochutla
# Processing Record 49 of Set 5 | mugia
# Processing Record 0 of Set 6 | avarua
# Processing Record 1 of Set 6 | fundao
# Processing Record 2 of Set 6 | borgo
# Processing Record 3 of Set 6 | aginskoye
# Processing Record 4 of Set 6 | zapolyarnyy
# Processing Record 5 of Set 6 | hayma'
# City not found. Skipping... ('coord')
# Processing Record 6 of Set 6 | dubovskoye
# Processing Record 7 of Set 6 | kerikeri
# Processing Record 8 of Set 6 | languyan
# Processing Record 9 of Set 6 | i-n-salah
# Processing Record 10 of Set 6 | khandyga
# Processing Record 11 of Set 6 | nahf
# Processing Record 12 of Set 6 | monrovia
# Processing Record 13 of Set 6 | saldanha
# Processing Record 14 of Set 6 | kodiak
# Processing Record 15 of Set 6 | uliastay
# Processing Record 16 of Set 6 | qarawul
# Processing Record 17 of Set 6 | qui nhon
# Processing Record 18 of Set 6 | plymstock
# Processing Record 19 of Set 6 | inarajan village
# Processing Record 20 of Set 6 | cururupu
# Processing Record 21 of Set 6 | aioun
# Processing Record 22 of Set 6 | flying fish cove
# Processing Record 23 of Set 6 | palmer
# Processing Record 24 of Set 6 | bei'an
# Processing Record 25 of Set 6 | sale
# Processing Record 26 of Set 6 | salinopolis
# Processing Record 27 of Set 6 | kharp
# Processing Record 28 of Set 6 | uruzgan
# Processing Record 29 of Set 6 | anshun
# Processing Record 30 of Set 6 | mount pleasant
# Processing Record 31 of Set 6 | el calafate
# Processing Record 32 of Set 6 | plastun
# Processing Record 33 of Set 6 | hammerfest
# Processing Record 34 of Set 6 | bikenibeu village
# Processing Record 35 of Set 6 | banjaran
# Processing Record 36 of Set 6 | grand falls-windsor
# Processing Record 37 of Set 6 | roquetas de mar
# Processing Record 38 of Set 6 | marsh harbour
# Processing Record 39 of Set 6 | newman
# Processing Record 40 of Set 6 | hotan
# Processing Record 41 of Set 6 | khilok
# Processing Record 42 of Set 6 | namibe
# Processing Record 43 of Set 6 | pagar alam
# Processing Record 44 of Set 6 | al qadarif
# Processing Record 45 of Set 6 | zaozersk
# Processing Record 46 of Set 6 | taro
# Processing Record 47 of Set 6 | hilo
# Processing Record 48 of Set 6 | kruisfontein
# Processing Record 49 of Set 6 | vega de alatorre
# Processing Record 0 of Set 7 | shimoda
# Processing Record 1 of Set 7 | sao felix do xingu
# Processing Record 2 of Set 7 | sirte
# Processing Record 3 of Set 7 | keflavik
# Processing Record 4 of Set 7 | prairie grove
# Processing Record 5 of Set 7 | juan de acosta
# Processing Record 6 of Set 7 | senador jose porfirio
# Processing Record 7 of Set 7 | mabaruma
# Processing Record 8 of Set 7 | chimoio
# Processing Record 9 of Set 7 | saynshand
# Processing Record 10 of Set 7 | ayorou
# Processing Record 11 of Set 7 | egilsstadir
# Processing Record 12 of Set 7 | tazacorte
# Processing Record 13 of Set 7 | seaside
# Processing Record 14 of Set 7 | askoy
# Processing Record 15 of Set 7 | crucecita
# Processing Record 16 of Set 7 | soio
# Processing Record 17 of Set 7 | richards bay
# Processing Record 18 of Set 7 | viseu
# Processing Record 19 of Set 7 | silver springs
# Processing Record 20 of Set 7 | praya
# Processing Record 21 of Set 7 | pundong
# Processing Record 22 of Set 7 | tadine
# Processing Record 23 of Set 7 | chonchi
# Processing Record 24 of Set 7 | qaqortoq
# Processing Record 25 of Set 7 | red deer
# Processing Record 26 of Set 7 | warah
# Processing Record 27 of Set 7 | vila franca do campo
# Processing Record 28 of Set 7 | dudinka
# Processing Record 29 of Set 7 | crane
# Processing Record 30 of Set 7 | punta arenas
# Processing Record 31 of Set 7 | maiduguri
# Processing Record 32 of Set 7 | wajir
# Processing Record 33 of Set 7 | las palmas
# Processing Record 34 of Set 7 | batticaloa
# Processing Record 35 of Set 7 | flin flon
# Processing Record 36 of Set 7 | tazovsky
# Processing Record 37 of Set 7 | makawao
# Processing Record 38 of Set 7 | bodaybo
# Processing Record 39 of Set 7 | gadzhiyevo
# Processing Record 40 of Set 7 | praia da vitoria
# Processing Record 41 of Set 7 | lee's summit
# Processing Record 42 of Set 7 | noumea
# Processing Record 43 of Set 7 | horta
# Processing Record 44 of Set 7 | rosso
# Processing Record 45 of Set 7 | ancud
# Processing Record 46 of Set 7 | carnarvon
# Processing Record 47 of Set 7 | novaya ladoga
# Processing Record 48 of Set 7 | kimovsk
# Processing Record 49 of Set 7 | nabire
# Processing Record 0 of Set 8 | mantua
# Processing Record 1 of Set 8 | kudat
# Processing Record 2 of Set 8 | vilyuchinsk
# Processing Record 3 of Set 8 | pimentel
# Processing Record 4 of Set 8 | toga village
# City not found. Skipping... ('coord')
# Processing Record 5 of Set 8 | palikir - national government center
# Processing Record 6 of Set 8 | palu
# Processing Record 7 of Set 8 | kolonia
# Processing Record 8 of Set 8 | zanjan
# Processing Record 9 of Set 8 | santa cruz cabralia
# Processing Record 10 of Set 8 | tallahassee
# Processing Record 11 of Set 8 | zarah sharan
# Processing Record 12 of Set 8 | ponta delgada
# Processing Record 13 of Set 8 | sao luiz gonzaga
# Processing Record 14 of Set 8 | olyokminsk
# Processing Record 15 of Set 8 | haugesund
# Processing Record 16 of Set 8 | pont rouge
# Processing Record 17 of Set 8 | fair plain
# Processing Record 18 of Set 8 | cozumel
# Processing Record 19 of Set 8 | bouarfa
# Processing Record 20 of Set 8 | lata
# Processing Record 21 of Set 8 | arraias
# Processing Record 22 of Set 8 | saipan
# Processing Record 23 of Set 8 | sinabang
# Processing Record 24 of Set 8 | puerto leguizamo
# Processing Record 25 of Set 8 | trondheim
# Processing Record 26 of Set 8 | 'ohonua
# City not found. Skipping... ('coord')
# Processing Record 27 of Set 8 | zheleznodorozhnyy
# Processing Record 28 of Set 8 | pariaman
# Processing Record 29 of Set 8 | general roca
# Processing Record 30 of Set 8 | kavieng
# Processing Record 31 of Set 8 | oamaru
# Processing Record 32 of Set 8 | uturoa
# Processing Record 33 of Set 8 | alaghsas
# Processing Record 34 of Set 8 | galesong
# Processing Record 35 of Set 8 | selkirk
# Processing Record 36 of Set 8 | port lincoln
# Processing Record 37 of Set 8 | beau vallon
# Processing Record 38 of Set 8 | ban phe
# City not found. Skipping... ('coord')
# Processing Record 39 of Set 8 | ikom
# Processing Record 40 of Set 8 | tagta
# Processing Record 41 of Set 8 | sitka
# Processing Record 42 of Set 8 | rikaze
# Processing Record 43 of Set 8 | macau
# Processing Record 44 of Set 8 | seogwipo
# City not found. Skipping... ('coord')
# Processing Record 45 of Set 8 | mili
# Processing Record 46 of Set 8 | poronaysk
# Processing Record 47 of Set 8 | lorengau
# Processing Record 48 of Set 8 | leninskiy
# Processing Record 49 of Set 8 | odda
# Processing Record 0 of Set 9 | mahdishahr
# Processing Record 1 of Set 9 | murzuq
# Processing Record 2 of Set 9 | san fernando de apure
# Processing Record 3 of Set 9 | laguna
# Processing Record 4 of Set 9 | kargil
# Processing Record 5 of Set 9 | kavaratti
# Processing Record 6 of Set 9 | misliyah
# Processing Record 7 of Set 9 | oltinko'l
# Processing Record 8 of Set 9 | kittila
# Processing Record 9 of Set 9 | pangani
# Processing Record 10 of Set 9 | jindabyne
# Processing Record 11 of Set 9 | rongelap
# Processing Record 12 of Set 9 | irtyshsk
# Processing Record 13 of Set 9 | illizi
# Processing Record 14 of Set 9 | bo rai
# Processing Record 15 of Set 9 | mianyang
# Processing Record 16 of Set 9 | notodden
# Processing Record 17 of Set 9 | challapata
# Processing Record 18 of Set 9 | ijebu-igbo
# Processing Record 19 of Set 9 | zhanaozen
# Processing Record 20 of Set 9 | karabash
# Processing Record 21 of Set 9 | protaras
# Processing Record 22 of Set 9 | ta`u
# Processing Record 23 of Set 9 | kitimat
# Processing Record 24 of Set 9 | hovd
# Processing Record 25 of Set 9 | lae
# Processing Record 26 of Set 9 | puerto deseado
# Processing Record 27 of Set 9 | brokopondo
# Processing Record 28 of Set 9 | mersing
# Processing Record 29 of Set 9 | tayu
# Processing Record 30 of Set 9 | fortuna
# Processing Record 31 of Set 9 | hancheng
# Processing Record 32 of Set 9 | ahau
# City not found. Skipping... ('coord')
# Processing Record 33 of Set 9 | bollnas
# Processing Record 34 of Set 9 | golpayegan
# Processing Record 35 of Set 9 | paidha
# Processing Record 36 of Set 9 | cidreira
# Processing Record 37 of Set 9 | mwinilunga
# Processing Record 38 of Set 9 | raja
# Processing Record 39 of Set 9 | baker city
# Processing Record 40 of Set 9 | thunder bay
# Processing Record 41 of Set 9 | rivne
# Processing Record 42 of Set 9 | naryn
# Processing Record 43 of Set 9 | aripuana
# Processing Record 44 of Set 9 | hasaki
# Processing Record 45 of Set 9 | tobi village
# City not found. Skipping... ('coord')
# Processing Record 46 of Set 9 | talata mafara
# Processing Record 47 of Set 9 | den burg
# Processing Record 48 of Set 9 | anyang-si
# Processing Record 49 of Set 9 | qal'at bishah
# City not found. Skipping... ('coord')
# Processing Record 0 of Set 10 | cill airne
# Processing Record 1 of Set 10 | ngaoundere
# Processing Record 2 of Set 10 | portage
# Processing Record 3 of Set 10 | kurara
# Processing Record 4 of Set 10 | dunedin
# Processing Record 5 of Set 10 | paradip garh
# Processing Record 6 of Set 10 | zabol
# Processing Record 7 of Set 10 | naranjal
# Processing Record 8 of Set 10 | yelizovo
# Processing Record 9 of Set 10 | dwarka
# Processing Record 10 of Set 10 | suomussalmi
# Processing Record 11 of Set 10 | toliara
# Processing Record 12 of Set 10 | la union
# Processing Record 13 of Set 10 | dauphin
# Processing Record 14 of Set 10 | grand-bassam
# Processing Record 15 of Set 10 | turkmenbasy
# Processing Record 16 of Set 10 | east london
# Processing Record 17 of Set 10 | trebic
# Processing Record 18 of Set 10 | rutland
# Processing Record 19 of Set 10 | susuman
# Processing Record 20 of Set 10 | mejit
# Processing Record 21 of Set 10 | kishni
# Processing Record 22 of Set 10 | villa gesell
# Processing Record 23 of Set 10 | mana
# Processing Record 24 of Set 10 | bam
# Processing Record 25 of Set 10 | taroa
# Processing Record 26 of Set 10 | arraial do cabo
# Processing Record 27 of Set 10 | virac
# Processing Record 28 of Set 10 | natal
# Processing Record 29 of Set 10 | kadom
# Processing Record 30 of Set 10 | les avirons
# Processing Record 31 of Set 10 | kangding
# Processing Record 32 of Set 10 | saint-philippe
# Processing Record 33 of Set 10 | antigonish
# Processing Record 34 of Set 10 | maswa
# Processing Record 35 of Set 10 | edd
# Processing Record 36 of Set 10 | ke-macina
# Processing Record 37 of Set 10 | port augusta
# Processing Record 38 of Set 10 | adh dhibiyah
# City not found. Skipping... ('coord')
# Processing Record 39 of Set 10 | cobija
# Processing Record 40 of Set 10 | dubbo
# Processing Record 41 of Set 10 | castelli
# Processing Record 42 of Set 10 | saint croix
# Processing Record 43 of Set 10 | ardestan
# Processing Record 44 of Set 10 | colonia
# Processing Record 45 of Set 10 | dawei
# Processing Record 46 of Set 10 | dakoutun
# Processing Record 47 of Set 10 | ballina
# Processing Record 48 of Set 10 | kalmunai
# Processing Record 49 of Set 10 | callao
# Processing Record 0 of Set 11 | lobujya
# Processing Record 1 of Set 11 | champerico
# Processing Record 2 of Set 11 | kill devil hills
# Processing Record 3 of Set 11 | caleta de carquin
# Processing Record 4 of Set 11 | opuwo
# Processing Record 5 of Set 11 | jiexiu
# Processing Record 6 of Set 11 | buritizeiro
# Processing Record 7 of Set 11 | beipiao
# Processing Record 8 of Set 11 | nemuro
# Processing Record 9 of Set 11 | brookings
# Processing Record 10 of Set 11 | berbera
# Processing Record 11 of Set 11 | darab
# Processing Record 12 of Set 11 | ochsenfurt
# Processing Record 13 of Set 11 | kencong
# Processing Record 14 of Set 11 | launceston
# Processing Record 15 of Set 11 | hamilton
# Processing Record 16 of Set 11 | tongchuanshi
# Processing Record 17 of Set 11 | kolyvan'
# Processing Record 18 of Set 11 | nueva imperial
# Processing Record 19 of Set 11 | sinop
# Processing Record 20 of Set 11 | okhotsk
# Processing Record 21 of Set 11 | hihifo
# City not found. Skipping... ('coord')
# Processing Record 22 of Set 11 | kolonia town
# Processing Record 23 of Set 11 | obidos
# Processing Record 24 of Set 11 | nikol'sk
# Processing Record 25 of Set 11 | xiva
# Processing Record 26 of Set 11 | benghazi
# Processing Record 27 of Set 11 | newborough
# Processing Record 28 of Set 11 | whitecourt
# Processing Record 29 of Set 11 | khorugh
# Processing Record 30 of Set 11 | caxias
# Processing Record 31 of Set 11 | portoferraio
# Processing Record 32 of Set 11 | selendi
# Processing Record 33 of Set 11 | qarazhal
# Processing Record 34 of Set 11 | okhansk
# Processing Record 35 of Set 11 | gebeit
# Processing Record 36 of Set 11 | pacocha
# Processing Record 37 of Set 11 | sola
# Processing Record 38 of Set 11 | acarau
# Processing Record 39 of Set 11 | carlow
# Processing Record 40 of Set 11 | hebron
# Processing Record 41 of Set 11 | nizhnyaya salda
# Processing Record 42 of Set 11 | rufino
# Processing Record 43 of Set 11 | luena
# Processing Record 44 of Set 11 | golfito
# Processing Record 45 of Set 11 | boende
# Processing Record 46 of Set 11 | naze
# Processing Record 47 of Set 11 | lodja
# Processing Record 48 of Set 11 | n'zeto
# Processing Record 49 of Set 11 | kamaishi
# Processing Record 0 of Set 12 | szczebrzeszyn
# Processing Record 1 of Set 12 | ad dabbah
# Processing Record 2 of Set 12 | musay'id
# City not found. Skipping... ('coord')
# Processing Record 3 of Set 12 | amalapuram
# Processing Record 4 of Set 12 | acapulco de juarez
# Processing Record 5 of Set 12 | am djarass
# City not found. Skipping... ('coord')
# Processing Record 6 of Set 12 | mitsamiouli
# Processing Record 7 of Set 12 | west wodonga
# Processing Record 8 of Set 12 | holualoa
# Processing Record 9 of Set 12 | hashtrud
# Processing Record 10 of Set 12 | shiqian
# Processing Record 11 of Set 12 | chinde
# Processing Record 12 of Set 12 | lazaro cardenas
# Processing Record 13 of Set 12 | strathalbyn
# Processing Record 14 of Set 12 | almeirim
# Processing Record 15 of Set 12 | haiku-pauwela
# Processing Record 16 of Set 12 | uray
# Processing Record 17 of Set 12 | namdrik
# Processing Record 18 of Set 12 | el paso
# Processing Record 19 of Set 12 | ambodifotatra
# Processing Record 20 of Set 12 | pampa
# Processing Record 21 of Set 12 | fannuj
# City not found. Skipping... ('coord')
# Processing Record 22 of Set 12 | nagqu
# Processing Record 23 of Set 12 | aykhal
# Processing Record 24 of Set 12 | catalina foothills
# Processing Record 25 of Set 12 | bangjun
# Processing Record 26 of Set 12 | astrakhan
# Processing Record 27 of Set 12 | mount pearl
# Processing Record 28 of Set 12 | zakamensk
# Processing Record 29 of Set 12 | carloforte
# Processing Record 30 of Set 12 | choibalsan
# Processing Record 31 of Set 12 | mranggen
# Processing Record 32 of Set 12 | bani walid
# Processing Record 33 of Set 12 | abraham's bay
# City not found. Skipping... ('coord')
# Processing Record 34 of Set 12 | pokhara
# Processing Record 35 of Set 12 | rukungiri
# Processing Record 36 of Set 12 | ghadamis
# Processing Record 37 of Set 12 | inhambane
# Processing Record 38 of Set 12 | ouellah
# City not found. Skipping... ('coord')
# Processing Record 39 of Set 12 | shwebo
# Processing Record 40 of Set 12 | lensk
# Processing Record 41 of Set 12 | arteche
# Processing Record 42 of Set 12 | ozery
# Processing Record 43 of Set 12 | tolanaro
# Processing Record 44 of Set 12 | pizarro
# Processing Record 45 of Set 12 | tezu
# Processing Record 46 of Set 12 | sumy
# Processing Record 47 of Set 12 | sur
# Processing Record 48 of Set 12 | anibare
# City not found. Skipping... ('coord')
# Processing Record 49 of Set 12 | puerto san carlos
# City not found. Skipping... ('coord')
# Processing Record 0 of Set 13 | kayes
# Processing Record 1 of Set 13 | riviere-du-loup
# Processing Record 2 of Set 13 | broome
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                prince rupert  54.3161 -130.3201     12.05        96
# 1                      jiuquan  39.7432   98.5174     14.29        25
# 2  edinburgh of the seven seas -37.0676  -12.3116     11.54        72
# 3                    yeraliyev  43.2000   51.6500     21.07        38
# 4  posto fiscal rolim de moura -13.0833  -62.2667     40.42        21
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        4.12      CA  1695835399
# 1           4        3.01      CN  1695835400
# 2          46       12.71      SH  1695835400
# 3           0        3.05      KZ  1695835401
# 4          34        1.98      BR  1695835401

# %%
# Export the City_Data into a csv
city_data_df.to_csv("C:\\Users\\jahn_\\Documents\\UofT\\GitHub\\Data-Analytics-Boot-Camp\\Module_6_API_Challenge\\Output_data\\cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("C:\\Users\\jahn_\\Documents\\UofT\\GitHub\\Data-Analytics-Boot-Camp\\Module_6_API_Challenge\\Output_data\\cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                      prince rupert  54.3161 -130.3201     12.05        96
# 1                            jiuquan  39.7432   98.5174     14.29        25
# 2        edinburgh of the seven seas -37.0676  -12.3116     11.54        72
# 3                          yeraliyev  43.2000   51.6500     21.07        38
# 4        posto fiscal rolim de moura -13.0833  -62.2667     40.42        21
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        4.12      CA  1695835399
# 1                 4        3.01      CN  1695835400
# 2                46       12.71      SH  1695835400
# 3                 0        3.05      KZ  1695835401
# 4                34        1.98      BR  1695835401

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for Latitude vs. Temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black", alpha=0.7)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

plt.grid(True)

# Save the figure
plt.savefig("C:\\Users\\jahn_\\Documents\\UofT\\GitHub\\Data-Analytics-Boot-Camp\\Module_6_API_Challenge\\Output_data\\Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for Latitude vs. Humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black", alpha=0.7)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.grid(True)

# Save the figure
plt.savefig("C:\\Users\\jahn_\\Documents\\UofT\\GitHub\\Data-Analytics-Boot-Camp\\Module_6_API_Challenge\\Output_data\\Fig2.png")

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for Latitude vs. Cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black", alpha=0.7)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.grid(True)

# Save the figure
plt.savefig("C:\\Users\\jahn_\\Documents\\UofT\\GitHub\\Data-Analytics-Boot-Camp\\Module_6_API_Challenge\\Output_data\\Fig3.png")

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for Latitude vs. Wind Speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black", alpha=0.7)

# Set title and labels
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Set grid lines
plt.grid(True)

# Save the figure
plt.savefig("C:\\Users\\jahn_\\Documents\\UofT\\GitHub\\Data-Analytics-Boot-Camp\\Module_6_API_Challenge\\Output_data\\Fig4.png")

# Show the plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
from scipy.stats import linregress

# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, filename):
   
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    plt.scatter(x_values, y_values, marker="o", alpha=1, label="Data Points")
    plt.plot(x_values, regress_values, "r-", label=f"Regression Line (R² = {round(rvalue**2, 2)})")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    
    equation_text = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    plt.annotate(equation_text, (min(x_values), min(y_values) + 5), fontsize=14, color="red")
    print(f"The r-value is: {rvalue**2}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        prince rupert  54.3161 -130.3201     12.05        96         100
# 1              jiuquan  39.7432   98.5174     14.29        25           4
# 3            yeraliyev  43.2000   51.6500     21.07        38           0
# 6               beihai  21.4833  109.1000     26.69        88         100
# 7             enewetak  11.3474  162.3373     28.62        77          99
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      CA  1695835399
# 1              3.01      CN  1695835400
# 3              3.05      KZ  1695835401
# 6              5.05      CN  1695835402
# 7              6.37      MH  1695835402

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 2        edinburgh of the seven seas -37.0676 -12.3116     11.54        72
# 4        posto fiscal rolim de moura -13.0833 -62.2667     40.42        21
# 5                            ushuaia -54.8000 -68.3000      5.79        48
# 8                     puerto natales -51.7236 -72.4875      2.25        80
# 10                         grytviken -54.2811 -36.5092      2.12        82
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                46       12.71      SH  1695835400
# 4                34        1.98      BR  1695835401
# 5                 0        2.57      AR  1695835286
# 8               100        1.03      CL  1695835403
# 10                9        3.73      GS  1695835404

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
x_label = "Latitude"
y_label = "Max Temp"

plot_linear_regression(x_values, y_values, x_label, y_label, title, filename)
# Out:
# The r-value is: 0.6243355886766764

# %%
# Filter data for Southern Hemisphere
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
x_label = "Latitude"
y_label = "Max Temp"
title = "Southern Hemisphere - Latitude vs. Max Temperature"
filename = "output_data/Southern_Hemi_Latitude_vs_Max_Temp.png"

plot_linear_regression(x_values, y_values, x_label, y_label, title, filename)
# Out:
# The r-value is: 0.6156491332765827

# %% [markdown]
# **Discussion about the linear relationship:** The first equation suggests a decrease in temperature with increasing latitude, while the second equation suggests an increase in temperature with increasing latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
#Northern Hemisphere
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
x_label = "Latitude"
y_label = "Humidity"
title = "Northern Hemisphere - Humidity vs. Latitude Linear Regression Plot"
filename = "output_data/Northern_Hemi_Humidity_vs_Latitude_Linear_Regression.png"

plot_linear_regression(x_values, y_values, x_label, y_label, title, filename)
# Out:
# The r-value is: 0.025929861296496614

# %%
#Southern Hemisphere
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
x_label = "Latitude"
y_label = "Humidity"
title = "Southern Hemisphere - Humidity vs. Latitude Linear Regression Plot"
filename = "output_data/Southern_Hemi_Humidity_vs_Latitude_Linear_Regression.png"

plot_linear_regression(x_values, y_values, x_label, y_label, title, filename)
# Out:
# The r-value is: 0.012891044219438427

# %% [markdown]
# **Discussion about the linear relationship:** In the first equation, as latitude increases, humidity increases at a rate of 0.2 units per unit increase in latitude. In the second equation, as latitude increases, humidity decreases at a rate of 0.17 units per unit increase in latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
#Northern Hemisphere
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
x_label = "Latitude"
y_label = "Cloudiness"
title = "Northern Hemisphere - Cloudiness vs. Latitude Linear Regression Plot"
filename = "output_data/Northern_Hemi_Cloudiness_vs_Latitude_Linear_Regression.png"

plot_linear_regression(x_values, y_values, x_label, y_label, title, filename)
# Out:
# The r-value is: 0.00799585767594948

# %%
#Southern Hemisphere
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
x_label = "Latitude"
y_label = "Cloudiness"
title = "Southern Hemisphere - Cloudiness vs. Latitude Linear Regression Plot"
filename = "output_data/Southern_Hemi_Cloudiness_vs_Latitude_Linear_Regression.png"

plot_linear_regression(x_values, y_values, x_label, y_label, title, filename)
# Out:
# The r-value is: 0.004343308985236559

# %% [markdown]
# **Discussion about the linear relationship:** Both linear regression equations suggest that there is a positive relationship between latitude and cloudiness, with cloudiness generally increasing as latitude increases, although the specific rates of increase differ slightly between the two equations.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
#Northern Hemisphere
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
x_label = "Latitude"
y_label = "Wind Speed"
title = "Northern Hemisphere - Wind Speed vs. Latitude Linear Regression Plot"
filename = "output_data/Northern_Hemi_Wind_Speed_vs_Latitude_Linear_Regression.png"

plot_linear_regression(x_values, y_values, x_label, y_label, title, filename)
# Out:
# The r-value is: 0.0197547078488758

# %%
#Southern Hemisphere
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
x_label = "Latitude"
y_label = "Wind Speed"
title = "Southern Hemisphere - Wind Speed vs. Latitude Linear Regression Plot"
filename = "output_data/Southern_Hemi_Wind_Speed_vs_Latitude_Linear_Regression.png"

plot_linear_regression(x_values, y_values, x_label, y_label, title, filename)
# Out:
# The r-value is: 0.009446519375935622

# %% [markdown]
# **Discussion about the linear relationship:** The above 2 plot suggests that there is a positive linear relationship between latitude and wind speed in the Northern Hemisphere and a negative linear relationship between latitude and wind speed in the Southern Hemisphere
